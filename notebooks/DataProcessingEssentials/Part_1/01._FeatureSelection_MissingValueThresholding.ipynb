# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# https://www.kaggle.com/hellbuoy/car-price-prediction

# %%
cars_data = pd.read_csv("datasets/car_price_data_null_values.csv")

cars_data.head(5)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0      111.0   5000.0    21.0
# 1        mpfi       3.47    2.68              9.0      111.0   5000.0    21.0
# 2        mpfi       2.68    3.47              9.0      154.0   5000.0    19.0
# 3        mpfi       3.19    3.40             10.0      102.0   5500.0    24.0
# 4        mpfi       3.19    3.40              8.0      115.0   5500.0     NaN
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Drop certain features so we're working with a more manageable dataset

# %%
cars_data.drop(["car_ID", "symboling", "CarName", "fueltype", "aspiration",
                "carbody", "enginelocation", "enginetype", "fuelsystem",
                "cylindernumber"], axis = 1, inplace = True)


cars_data.head(5)
# Out:
#   doornumber drivewheel  wheelbase  carlength  carwidth  carheight  \
# 0        two        rwd       88.6      168.8      64.1       48.8
# 1        two        rwd       88.6      168.8      64.1       48.8
# 2        two        rwd       94.5      171.2      65.5       52.4
# 3       four        fwd       99.8      176.6      66.2       54.3
# 4       four        4wd       99.4      176.6      66.4       54.3
#
#    curbweight  enginesize  boreratio  stroke  compressionratio  horsepower  \
# 0        2548         130       3.47    2.68               9.0       111.0
# 1        2548         130       3.47    2.68               9.0       111.0
# 2        2823         152       2.68    3.47               9.0       154.0
# 3        2337         109       3.19    3.40              10.0       102.0
# 4        2824         136       3.19    3.40               8.0       115.0
#
#    peakrpm  citympg  highwaympg    price
# 0   5000.0     21.0          27  13495.0
# 1   5000.0     21.0          27  16500.0
# 2   5000.0     19.0          26  16500.0
# 3   5500.0     24.0          30  13950.0
# 4   5500.0      NaN          22  17450.0

# %% [markdown]
# ### Label encode the doornumber feature i.e. represent each categorical variable with a unique integer value

# %%
doornumber_dict = {'two':0, 'four':1}

cars_data['doornumber'].replace(doornumber_dict, inplace=True)

cars_data.head()
# Out:
#    doornumber drivewheel  wheelbase  carlength  carwidth  carheight  \
# 0           0        rwd       88.6      168.8      64.1       48.8
# 1           0        rwd       88.6      168.8      64.1       48.8
# 2           0        rwd       94.5      171.2      65.5       52.4
# 3           1        fwd       99.8      176.6      66.2       54.3
# 4           1        4wd       99.4      176.6      66.4       54.3
#
#    curbweight  enginesize  boreratio  stroke  compressionratio  horsepower  \
# 0        2548         130       3.47    2.68               9.0       111.0
# 1        2548         130       3.47    2.68               9.0       111.0
# 2        2823         152       2.68    3.47               9.0       154.0
# 3        2337         109       3.19    3.40              10.0       102.0
# 4        2824         136       3.19    3.40               8.0       115.0
#
#    peakrpm  citympg  highwaympg    price
# 0   5000.0     21.0          27  13495.0
# 1   5000.0     21.0          27  16500.0
# 2   5000.0     19.0          26  16500.0
# 3   5500.0     24.0          30  13950.0
# 4   5500.0      NaN          22  17450.0

# %% [markdown]
# ### Represent each value of the categorical variable in one-hot encoded form
#
# - The original `drivewheel` column is replaced with 3 columns `drivewheel_4wd`, `drivewheel_fwd`, and `drivewheel_rwd`

# %%
cars_data = pd.get_dummies(cars_data, columns=['drivewheel'])

cars_data.head()
# Out:
#    doornumber  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0           0       88.6      168.8      64.1       48.8        2548
# 1           0       88.6      168.8      64.1       48.8        2548
# 2           0       94.5      171.2      65.5       52.4        2823
# 3           1       99.8      176.6      66.2       54.3        2337
# 4           1       99.4      176.6      66.4       54.3        2824
#
#    enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0         130       3.47    2.68               9.0       111.0   5000.0
# 1         130       3.47    2.68               9.0       111.0   5000.0
# 2         152       2.68    3.47               9.0       154.0   5000.0
# 3         109       3.19    3.40              10.0       102.0   5500.0
# 4         136       3.19    3.40               8.0       115.0   5500.0
#
#    citympg  highwaympg    price  drivewheel_4wd  drivewheel_fwd  \
# 0     21.0          27  13495.0               0               0
# 1     21.0          27  16500.0               0               0
# 2     19.0          26  16500.0               0               0
# 3     24.0          30  13950.0               0               1
# 4      NaN          22  17450.0               1               0
#
#    drivewheel_rwd
# 0               1
# 1               1
# 2               1
# 3               0
# 4               0

# %%
cars_data.drop(["doornumber", "drivewheel_4wd", "drivewheel_fwd", "drivewheel_rwd"], 
               axis = 1, inplace = False).replace(0, np.nan, inplace = True)

cars_data.isna().sum()
# Out:
# doornumber            0
# wheelbase            10
# carlength             0
# carwidth              0
# carheight             0
# curbweight            0
# enginesize            0
# boreratio           104
# stroke               45
# compressionratio    133
# horsepower            4
# peakrpm               3
# citympg             180
# highwaympg            0
# price                 0
# drivewheel_4wd        0
# drivewheel_fwd        0
# drivewheel_rwd        0
# dtype: int64

# %% [markdown]
# ### Calculate what percentage of the records have missing values for each of these fields

# %%
cars_data["peakrpm"].isna().sum() / len(cars_data) * 100
# Out:
# 1.4634146341463417

# %%
cars_data["wheelbase"].isna().sum() / len(cars_data) * 100
# Out:
# 4.878048780487805

# %%
cars_data["stroke"].isna().sum() / len(cars_data) * 100
# Out:
# 21.951219512195124

# %%
cars_data["citympg"].isna().sum() / len(cars_data) * 100
# Out:
# 87.8048780487805

# %%
cars_data["compressionratio"].isna().sum() / len(cars_data) * 100
# Out:
# 64.8780487804878

# %%
cars_data["boreratio"].isna().sum() / len(cars_data) * 100
# Out:
# 50.73170731707317

# %%
cars_data.columns
# Out:
# Index(['doornumber', 'wheelbase', 'carlength', 'carwidth', 'carheight',
#        'curbweight', 'enginesize', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price',
#        'drivewheel_4wd', 'drivewheel_fwd', 'drivewheel_rwd'],
#       dtype='object')

# %% [markdown]
# ### Choose a missing value threshold of 50%, columns with more than 50% of the data missing will be dropped

# %%
cars_data_trimmed = cars_data.dropna(thresh = int(cars_data.shape[0] * .50), axis = 1)

cars_data_trimmed.head()
# Out:
#    doornumber  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0           0       88.6      168.8      64.1       48.8        2548
# 1           0       88.6      168.8      64.1       48.8        2548
# 2           0       94.5      171.2      65.5       52.4        2823
# 3           1       99.8      176.6      66.2       54.3        2337
# 4           1       99.4      176.6      66.4       54.3        2824
#
#    enginesize  stroke  horsepower  peakrpm  highwaympg    price  \
# 0         130    2.68       111.0   5000.0          27  13495.0
# 1         130    2.68       111.0   5000.0          27  16500.0
# 2         152    3.47       154.0   5000.0          26  16500.0
# 3         109    3.40       102.0   5500.0          30  13950.0
# 4         136    3.40       115.0   5500.0          22  17450.0
#
#    drivewheel_4wd  drivewheel_fwd  drivewheel_rwd
# 0               0               0               1
# 1               0               0               1
# 2               0               0               1
# 3               0               1               0
# 4               1               0               0

# %%
cars_data_trimmed = cars_data_trimmed.fillna(cars_data_trimmed.mean())

cars_data_trimmed.isna().sum()
# Out:
# doornumber        0
# wheelbase         0
# carlength         0
# carwidth          0
# carheight         0
# curbweight        0
# enginesize        0
# stroke            0
# horsepower        0
# peakrpm           0
# highwaympg        0
# price             0
# drivewheel_4wd    0
# drivewheel_fwd    0
# drivewheel_rwd    0
# dtype: int64

# %%
x = cars_data_trimmed.drop(["price"], axis = 1)

y = cars_data_trimmed["price"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size =  0.25)

x_train.head()
# Out:
#      doornumber   wheelbase  carlength  carwidth  carheight  curbweight  \
# 123           1  103.300000      174.6      64.6       59.8        2535
# 160           1   95.700000      166.3      64.4       53.0        2094
# 27            0   98.924103      157.3      63.8       50.6        2191
# 169           0   98.400000      176.2      65.6       52.0        2551
# 101           1  100.400000      181.7      66.5       55.1        3095
#
#      enginesize  stroke  horsepower  peakrpm  highwaympg  drivewheel_4wd  \
# 123         122   3.460        88.0   5000.0          30               0
# 160          98   3.242        70.0   4800.0          47               0
# 27           98   3.390       102.0   5500.0          30               0
# 169         146   3.242       116.0   4800.0          30               0
# 101         181   3.270       152.0   5200.0          22               0
#
#      drivewheel_fwd  drivewheel_rwd
# 123               1               0
# 160               1               0
# 27                1               0
# 169               0               1
# 101               1               0

# %%
linear_model = LinearRegression().fit(x_train, y_train)

print("Training Score :", linear_model.score(x_train, y_train))
# Out:
# Training Score : 0.8706998028758303

# %%
y_pred = linear_model.predict(x_test)

print("Testing Score :", r2_score(y_test, y_pred))
# Out:
# Testing Score : 0.7413313497941009
